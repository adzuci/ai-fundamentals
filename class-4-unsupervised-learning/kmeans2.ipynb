# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans

# %%
stud_data={
       "Study_Hours":[2,4,6,8,10,12,3,5,7,9],
       "Sleep_Hours":[9,8,7,6,5,4,9,8,6,5]
}

# %%
df=pd.DataFrame(stud_data)

# %%
df
# Out:
#    Study_Hours  Sleep_Hours
# 0            2            9
# 1            4            8
# 2            6            7
# 3            8            6
# 4           10            5
# 5           12            4
# 6            3            9
# 7            5            8
# 8            7            6
# 9            9            5

# %%
plt.scatter(df["Study_Hours"],df["Sleep_Hours"])
plt.xlabel("Study_Hours")
plt.ylabel("Sleep_Hours")
plt.title("Students Data ")
plt.show()

# %%
kms=KMeans(n_clusters=2,random_state=42)
kms.fit(df)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
df["Cluster"]=kms.labels_

# %%
df
# Out:
#    Study_Hours  Sleep_Hours  Cluster
# 0            2            9        1
# 1            4            8        1
# 2            6            7        1
# 3            8            6        0
# 4           10            5        0
# 5           12            4        0
# 6            3            9        1
# 7            5            8        1
# 8            7            6        0
# 9            9            5        0

# %%
plt.scatter(df["Study_Hours"], df["Sleep_Hours"], c=df["Cluster"])
plt.xlabel("Study_Hours")
plt.ylabel("Sleep_Hours")
plt.title("Students Data (colored by cluster)")
plt.show()
