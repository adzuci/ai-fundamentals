# %% [markdown]
# # Class 2 Notebook
#
# This notebook is for hands-on exercises in Class 2.
#
# Run the first cell to confirm your environment works in both macOS and Windows.

# %%
import platform

print("Python:", platform.python_version())
print("OS:", platform.system(), platform.release())

# Quick sanity checks for Jupyter data tooling
try:
    import numpy as np
    import pandas as pd

    print("NumPy:", np.__version__)
    print("Pandas:", pd.__version__)
    sample = pd.DataFrame({"x": [1, 2, 3], "y": [10, 20, 30]})
    print(sample)
except ModuleNotFoundError as exc:
    print("Optional dependency missing:", exc)
    print("Install with: python -m pip install numpy pandas")
